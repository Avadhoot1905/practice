# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

# %%
np.random.seed(42)

# %%
X = 2 * np.random.rand(100,1)
y = 4 + 3 * X + np.random.rand(100,1)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, ran
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.scatter(X_train, y_train, color = 'blue', label = 'training data')
plt.scatter(X_test, y_test, color = 'red', label = 'testing data')
plt.plot(X_test, y_pred, color = 'black', linewidth = 3, label = 'regression
plt.show()

# %%
df = pd.read_csv("/home/anaconda/Downloads/loan.csv")
df.head()

# %%
model = LogisticRegression()
plt.scatter(df.age, df.loan, color = 'red')

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(df[['age']], df.loan_status, test_size=0.2, random_state=42)
X1_test

# %%
model.fit(X1_train, y1_train)
model.predict(X1_test)

# %%
model.score(X1_test, y1_test)

# %%
model.predict_proba(X1_test)

# %%
confusion_matrix(y1_test, model.predict(X1_test))

# %%
print(classification_report(y1_test, model.predict(X1_test)))
